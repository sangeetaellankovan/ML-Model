# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns #visualization

# %%
hdb=pd.read_csv("FINAL_clean_merged_data_09102021.csv")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (4,5,6,9,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
hdb.head(10)
# Out:
#             Project Name          Street Name         Type  Postal District  \
# 0                  ARTRA       ALEXANDRA VIEW    Apartment              3.0
# 1                SEAHILL  WEST COAST CRESCENT  Condominium              5.0
# 2    HIGHLINE RESIDENCES        KIM TIAN ROAD  Condominium              3.0
# 3           THE SPECTRUM   PASIR PANJANG ROAD  Condominium              5.0
# 4             THE VISION  WEST COAST CRESCENT  Condominium              5.0
# 5      WALLICH RESIDENCE       WALLICH STREET    Apartment              2.0
# 6  THE BERTH BY THE COVE          OCEAN DRIVE  Condominium              4.0
# 7   ONE-NORTH RESIDENCES    ONE-NORTH GATEWAY    Apartment              5.0
# 8                 CLAVON    CLEMENTI AVENUE 1    Apartment              5.0
# 9                 CLAVON    CLEMENTI AVENUE 1    Apartment              5.0
#
#   Market Segment                             Tenure Type of Sale  \
# 0            RCR  99 yrs lease commencing from 2016     Sub Sale
# 1            OCR  99 yrs lease commencing from 2011       Resale
# 2            RCR  99 yrs lease commencing from 2013       Resale
# 3            RCR                           Freehold       Resale
# 4            OCR  99 yrs lease commencing from 2008       Resale
# 5            CCR  99 yrs lease commencing from 2011       Resale
# 6            CCR  99 yrs lease commencing from 2004       Resale
# 7            RCR  99 yrs lease commencing from 2005       Resale
# 8            OCR  99 yrs lease commencing from 2019     New Sale
# 9            OCR  99 yrs lease commencing from 2019     New Sale
#
#    No. of Units  Price ($) Nett Price ($)  ...  \
# 0             1  1525000.0              -  ...
# 1             1   700000.0              -  ...
# 2             1  2130000.0              -  ...
# 3             1  1560000.0              -  ...
# 4             1  1225000.0              -  ...
# 5             1  2325000.0              -  ...
# 6             1  2140000.0              -  ...
# 7             1  1760000.0              -  ...
# 8             1  2019000.0              -  ...
# 9             1  2203000.0              -  ...
#
#                            Hawker MRT Latitude MRT Longitude  Nearest MRT(km)  \
# 0        Blk 115 Bukit Merah View     1.289674    103.816787         0.059461
# 1  Blk 726 Clementi West Street 2     1.314925    103.765341         1.814662
# 2              Tiong Bahru Market     1.286555    103.826956         0.338635
# 3  Blk 726 Clementi West Street 2     1.283149    103.781991         1.725470
# 4  Blk 726 Clementi West Street 2     1.314925    103.765341         1.862553
# 5         Amoy Street Food Centre     1.276385    103.846771         0.136134
# 6       Blk 6 Tanjong Pagar Plaza     1.276385    103.846771         2.929836
# 7             Tanglin Halt Market     1.299854    103.787584         0.367570
# 8          Blk 448 Clementi Ave 3     1.314925    103.765341         0.739126
# 9          Blk 448 Clementi Ave 3     1.314925    103.765341         0.739126
#
#              MRT  School Latitude  School Longitude  \
# 0        Redhill         1.291299        103.823941
# 1       Clementi         1.312622        103.757030
# 2    Tiong Bahru         1.284498        103.826149
# 3  Haw Par Villa         1.300799        103.785692
# 4       Clementi         1.312622        103.757030
# 5  Tanjong Pagar         1.286387        103.837073
# 6  Tanjong Pagar         1.286387        103.837073
# 7      one-north         1.300799        103.785692
# 8       Clementi         1.315809        103.763055
# 9       Clementi         1.315809        103.763055
#
#    Nearest Primary School(km)                        Primary School  \
# 0                    0.764354              Alexandra Primary School
# 1                    1.741619                   Qifa Primary School
# 2                    0.417839                Zhangde Primary School
# 3                    2.144825  Fairfield Methodist School (Primary)
# 4                    1.812577                   Qifa Primary School
# 5                    1.415243              Palm View Primary School
# 6                    4.170715              Palm View Primary School
# 7                    0.494135  Fairfield Methodist School (Primary)
# 8                    0.926506               Clementi Primary School
# 9                    0.926506               Clementi Primary School
#
#    Primary School Rank
# 0                101.0
# 1                103.0
# 2                163.0
# 3                 15.0
# 4                103.0
# 5                124.0
# 6                124.0
# 7                 15.0
# 8                121.0
# 9                121.0
#
# [10 rows x 31 columns]

# %%
#hdb = hdb.drop(columns=['MRT Latitude', 'MRT Longitude','School Latitude', 'School Longitude','Hawker Longitude','Hawker Latitude'])
#hdb = hdb.drop(columns=['Hawker Longitude','Hawker Latitude'])

hdb = hdb.drop(columns=['Longitude','Latitude'])

# %%
hdb.head(10)
# Out:
#             Project Name          Street Name         Type  Postal District  \
# 0                  ARTRA       ALEXANDRA VIEW    Apartment              3.0
# 1                SEAHILL  WEST COAST CRESCENT  Condominium              5.0
# 2    HIGHLINE RESIDENCES        KIM TIAN ROAD  Condominium              3.0
# 3           THE SPECTRUM   PASIR PANJANG ROAD  Condominium              5.0
# 4             THE VISION  WEST COAST CRESCENT  Condominium              5.0
# 5      WALLICH RESIDENCE       WALLICH STREET    Apartment              2.0
# 6  THE BERTH BY THE COVE          OCEAN DRIVE  Condominium              4.0
# 7   ONE-NORTH RESIDENCES    ONE-NORTH GATEWAY    Apartment              5.0
# 8                 CLAVON    CLEMENTI AVENUE 1    Apartment              5.0
# 9                 CLAVON    CLEMENTI AVENUE 1    Apartment              5.0
#
#   Market Segment                             Tenure Type of Sale  \
# 0            RCR  99 yrs lease commencing from 2016     Sub Sale
# 1            OCR  99 yrs lease commencing from 2011       Resale
# 2            RCR  99 yrs lease commencing from 2013       Resale
# 3            RCR                           Freehold       Resale
# 4            OCR  99 yrs lease commencing from 2008       Resale
# 5            CCR  99 yrs lease commencing from 2011       Resale
# 6            CCR  99 yrs lease commencing from 2004       Resale
# 7            RCR  99 yrs lease commencing from 2005       Resale
# 8            OCR  99 yrs lease commencing from 2019     New Sale
# 9            OCR  99 yrs lease commencing from 2019     New Sale
#
#    No. of Units  Price ($) Nett Price ($)  ...  \
# 0             1  1525000.0              -  ...
# 1             1   700000.0              -  ...
# 2             1  2130000.0              -  ...
# 3             1  1560000.0              -  ...
# 4             1  1225000.0              -  ...
# 5             1  2325000.0              -  ...
# 6             1  2140000.0              -  ...
# 7             1  1760000.0              -  ...
# 8             1  2019000.0              -  ...
# 9             1  2203000.0              -  ...
#
#                            Hawker MRT Latitude MRT Longitude  Nearest MRT(km)  \
# 0        Blk 115 Bukit Merah View     1.289674    103.816787         0.059461
# 1  Blk 726 Clementi West Street 2     1.314925    103.765341         1.814662
# 2              Tiong Bahru Market     1.286555    103.826956         0.338635
# 3  Blk 726 Clementi West Street 2     1.283149    103.781991         1.725470
# 4  Blk 726 Clementi West Street 2     1.314925    103.765341         1.862553
# 5         Amoy Street Food Centre     1.276385    103.846771         0.136134
# 6       Blk 6 Tanjong Pagar Plaza     1.276385    103.846771         2.929836
# 7             Tanglin Halt Market     1.299854    103.787584         0.367570
# 8          Blk 448 Clementi Ave 3     1.314925    103.765341         0.739126
# 9          Blk 448 Clementi Ave 3     1.314925    103.765341         0.739126
#
#              MRT  School Latitude  School Longitude  \
# 0        Redhill         1.291299        103.823941
# 1       Clementi         1.312622        103.757030
# 2    Tiong Bahru         1.284498        103.826149
# 3  Haw Par Villa         1.300799        103.785692
# 4       Clementi         1.312622        103.757030
# 5  Tanjong Pagar         1.286387        103.837073
# 6  Tanjong Pagar         1.286387        103.837073
# 7      one-north         1.300799        103.785692
# 8       Clementi         1.315809        103.763055
# 9       Clementi         1.315809        103.763055
#
#    Nearest Primary School(km)                        Primary School  \
# 0                    0.764354              Alexandra Primary School
# 1                    1.741619                   Qifa Primary School
# 2                    0.417839                Zhangde Primary School
# 3                    2.144825  Fairfield Methodist School (Primary)
# 4                    1.812577                   Qifa Primary School
# 5                    1.415243              Palm View Primary School
# 6                    4.170715              Palm View Primary School
# 7                    0.494135  Fairfield Methodist School (Primary)
# 8                    0.926506               Clementi Primary School
# 9                    0.926506               Clementi Primary School
#
#   Primary School Rank
# 0               101.0
# 1               103.0
# 2               163.0
# 3                15.0
# 4               103.0
# 5               124.0
# 6               124.0
# 7                15.0
# 8               121.0
# 9               121.0
#
# [10 rows x 29 columns]

# %%
hdb1 = hdb.drop(columns=['No. of Units', 'Postal Code', 'Unit Price ($psf)'])

# %%
hdb2 = hdb1[hdb1.columns.drop(list(hdb1.filter(regex='Latitude')))]

# %%
hdbcorr = hdb2[hdb2.columns.drop(list(hdb2.filter(regex='Longitude')))]

# %%
#We want to try to find out which variables are useful than the others and 
#are there any variables which you can eliminate

cor = hdbcorr.corr(method='kendall')

#by default it uses Pearson Correlation coefficient

#correlation quantifies the relationship between the variables (-1 to 1)

plt.figure(figsize=(20,20))

sns.heatmap(cor,annot = True)

# %%
hdbcorr.head(10)
# Out:
#             Project Name          Street Name         Type  Postal District  \
# 0                  ARTRA       ALEXANDRA VIEW    Apartment              3.0
# 1                SEAHILL  WEST COAST CRESCENT  Condominium              5.0
# 2    HIGHLINE RESIDENCES        KIM TIAN ROAD  Condominium              3.0
# 3           THE SPECTRUM   PASIR PANJANG ROAD  Condominium              5.0
# 4             THE VISION  WEST COAST CRESCENT  Condominium              5.0
# 5      WALLICH RESIDENCE       WALLICH STREET    Apartment              2.0
# 6  THE BERTH BY THE COVE          OCEAN DRIVE  Condominium              4.0
# 7   ONE-NORTH RESIDENCES    ONE-NORTH GATEWAY    Apartment              5.0
# 8                 CLAVON    CLEMENTI AVENUE 1    Apartment              5.0
# 9                 CLAVON    CLEMENTI AVENUE 1    Apartment              5.0
#
#   Market Segment                             Tenure Type of Sale  Price ($)  \
# 0            RCR  99 yrs lease commencing from 2016     Sub Sale  1525000.0
# 1            OCR  99 yrs lease commencing from 2011       Resale   700000.0
# 2            RCR  99 yrs lease commencing from 2013       Resale  2130000.0
# 3            RCR                           Freehold       Resale  1560000.0
# 4            OCR  99 yrs lease commencing from 2008       Resale  1225000.0
# 5            CCR  99 yrs lease commencing from 2011       Resale  2325000.0
# 6            CCR  99 yrs lease commencing from 2004       Resale  2140000.0
# 7            RCR  99 yrs lease commencing from 2005       Resale  1760000.0
# 8            OCR  99 yrs lease commencing from 2019     New Sale  2019000.0
# 9            OCR  99 yrs lease commencing from 2019     New Sale  2203000.0
#
#   Nett Price ($)  Area (Sqft) Type of Area Floor Level Date of Sale  \
# 0              -        829.0       Strata    06 to 10       1/8/21
# 1              -        506.0       Strata    11 to 15       1/8/21
# 2              -       1130.0       Strata    01 to 05       1/8/21
# 3              -       1270.0       Strata    01 to 05       1/8/21
# 4              -        904.0       Strata    31 to 35       1/8/21
# 5              -        646.0       Strata    46 to 50       1/8/21
# 6              -       1647.0       Strata    01 to 05       1/8/21
# 7              -       1109.0       Strata    11 to 15       1/8/21
# 8              -       1356.0       Strata    01 to 05       1/8/21
# 9              -       1356.0       Strata    26 to 30       1/8/21
#
#    Nearest Hawker(km)                          Hawker  Nearest MRT(km)  \
# 0            0.720735        Blk 115 Bukit Merah View         0.059461
# 1            0.573486  Blk 726 Clementi West Street 2         1.814662
# 2            0.275826              Tiong Bahru Market         0.338635
# 3            1.472236  Blk 726 Clementi West Street 2         1.725470
# 4            0.625836  Blk 726 Clementi West Street 2         1.862553
# 5            0.265156         Amoy Street Food Centre         0.136134
# 6            2.975668       Blk 6 Tanjong Pagar Plaza         2.929836
# 7            0.890124             Tanglin Halt Market         0.367570
# 8            0.605647          Blk 448 Clementi Ave 3         0.739126
# 9            0.605647          Blk 448 Clementi Ave 3         0.739126
#
#              MRT  Nearest Primary School(km)  \
# 0        Redhill                    0.764354
# 1       Clementi                    1.741619
# 2    Tiong Bahru                    0.417839
# 3  Haw Par Villa                    2.144825
# 4       Clementi                    1.812577
# 5  Tanjong Pagar                    1.415243
# 6  Tanjong Pagar                    4.170715
# 7      one-north                    0.494135
# 8       Clementi                    0.926506
# 9       Clementi                    0.926506
#
#                          Primary School  Primary School Rank
# 0              Alexandra Primary School                101.0
# 1                   Qifa Primary School                103.0
# 2                Zhangde Primary School                163.0
# 3  Fairfield Methodist School (Primary)                 15.0
# 4                   Qifa Primary School                103.0
# 5              Palm View Primary School                124.0
# 6              Palm View Primary School                124.0
# 7  Fairfield Methodist School (Primary)                 15.0
# 8               Clementi Primary School                121.0
# 9               Clementi Primary School                121.0
